# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Kushal11608202/ML--1/blob/master/Untitled14.ipynb)

# %%
import pandas as pd
import seaborn as sns
sns.despine()
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
g = sns.countplot(x = 'RainToday' , data = df)
# g.set_title('0->NO 1->YES')

# %%
sns.distplot(df['MaxTemp'])

# %%
sns.boxplot(x = 'Rainfall' , data = df)

# %%
sns.boxplot(x = 'WindGustDir' , y = 'Rainfall' , data = df)

# %%
sns.violinplot(x = 'WindGustSpeed' , y = 'WindGustDir' , data = df)

# %%
sns.boxplot(x = 'WindDir9am' , y = 'Rainfall' , hue = 'WindGustDir' , data = df)

# %%
sns.violinplot(x = 'WindGustDir' , y = 'Pressure9am' , hue = 'WindDir9am' , data = df , Split = True , inner = 'stick')

# %%
sns.jointplot(x = 'Evaporation' , y = 'Pressure9am' , data = df , alpha = 0.2)

# %%
sns.jointplot(x = 'Evaporation' , y = 'Pressure9am' , data = df , alpha = 0.2 , kind = 'hex')

# %%
sns.jointplot(x = 'Evaporation' , y = 'Pressure9am' , data = df , alpha = 0.2 , kind = 'kde')

# %%
dfg = df.groupby(by = 'WindDir9am').agg(['sum','mean'])

# %%
dfg['Rainfall']['sum'].plot(kind = 'barh')

# %%
dfg['MaxTemp']['mean'].plot(kind = 'bar')

# %%
dfg['Rainfall']['mean'].plot(kind = 'pie')

# %%
dfg['MaxTemp']['sum'].plot(kind = 'area')

# %%
dfg['Rainfall']['sum'].plot(kind = 'hist')

# %%
dfg['MinTemp']['mean'].plot(kind = 'kde')

# %%
df.plot.hexbin(x = 'Evaporation' , y = 'Pressure9am' , gridsize = 25)

# %%
df.plot.scatter(x = 'Evaporation' , y = 'Pressure9am')

# %%
dfg['Rainfall']['sum'].plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f817f85bfd0>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2 , diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8179bc6cd0>,
# ...
#       dtype=object)
